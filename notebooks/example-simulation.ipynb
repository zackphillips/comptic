# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

import comptic.simulation as sim
import matplotlib.pyplot as plt
import llops as yp
import math

# %% [markdown]
# ## Gallery of Available Test Objects

# %%
# Get list of available objects
test_object_list = sim.get_available_objects()

x_size = 5
y_size = math.ceil(len(test_object_list) / x_size)

plt.figure(figsize=(12, 3 * y_size))

for index, label in enumerate(test_object_list):
    test_object = sim.testObject(label)
    
    plt.subplot(y_size, x_size, index + 1)
    plt.imshow(yp.real(test_object))
    plt.title(label)
# Out:
# <img src="data:image/png;base64,..." width="600">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-547aa549f0c4> in <module>
#       8
#       9 for index, label in enumerate(test_object_list):
# ---> 10     test_object = sim.testObject(label)
#      11
#      12     plt.subplot(y_size, x_size, index + 1)
#
# ~/develop/comptic/comptic/simulation.py in testObject(absorption, shape, phase, dtype, backend, **kwargs)
#      86     # Normalize
#      87     test_object -= yp.min(test_object)
# ---> 88     test_object /= yp.max(test_object)
#      89
#      90     # Apply correct range to absorption
#
# TypeError: No loop matching the specified signature and casting
# was found for ufunc true_divide

# %%
import arrayfire

# %%
# %timeit a = arrayfire.vision.orb(sim.cameraman(backend='arrayfire', dtype='float32'))
# Out:
# 7.54 ms ± 88.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ### Getting images from skimage

# %%
import skimage
import imageio
img = skimage.data.chelsea()

# imageio.imwrite('../resources/testimages/chelsea.tiff', img)

# %% [markdown]
# ## Specific Objects

# %%
a = sim.ucb()
plt.figure()
plt.subplot(121)
plt.imshow(yp.abs(a))
plt.colorbar()
plt.title('Amplitude')

plt.subplot(122)
plt.imshow(yp.angle(a))
plt.colorbar()
plt.title('Phase')
# Out:
# <img src="data:image/png;base64,..." width="1200">
# Text(0.5, 1.0, 'Phase')

# %%
a = sim.cells()
plt.figure()
plt.subplot(121)
plt.imshow(yp.abs(a))
plt.colorbar()
plt.title('Amplitude')

plt.subplot(122)
plt.imshow(yp.angle(a))
plt.colorbar()
plt.title('Phase')

# %%
a = sim.brain()
plt.figure()
plt.imshow(yp.abs(a))
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
a = sim.cameraman()
plt.figure()
plt.imshow(yp.abs(a))
plt.colorbar()

# %%
a = sim.letters()
plt.figure()
plt.imshow(yp.abs(a))
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %% [markdown]
# ## Testing Reshape Operation

# %%
img = sim.brain(shape=(500,100))

plt.figure()
plt.imshow(yp.abs(img))
# Out:
# <img src="data:image/png;base64,..." width="1200">
