# %% [markdown]
# # Differential Phase Contrast

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

import pydpc
import llops as yp
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-1cf6f9d19f9f> in <module>
#       3 get_ipython().run_line_magic('matplotlib', 'notebook')
#       4
# ----> 5 import pydpc
#       6 import llops as yp
#
# ~/.conda/lib/python3.8/site-packages/pydpc/__init__.py in <module>
# ----> 1 from .dpc import *
#       2 from . import analysis
#
# ~/.conda/lib/python3.8/site-packages/pydpc/dpc.py in <module>
#       3 import llops as yp
#       4 import matplotlib.pyplot as plt
# ----> 5 import comptic
#       6
#       7 # Valid source types used in the functions below
#
# ~/.conda/lib/python3.8/site-packages/comptic/__init__.py in <module>
#       2 from . import imaging
#       3 from . import wotf
# ----> 4 from . import ledarray
#       5 from . import noise
# ...

# %% [markdown]
# ## Generate Rasterized (2D) Source Lists

# %%
# Generate all sources
source_list = [pydpc.genDpcSourceList((100,100), source_label) for source_label in pydpc.valid_source_types]

# Plot
yp.listPlotFlat(source_list, pydpc.valid_source_types, figsize=(14,10))
# Out:
# <img src="data:image/png;base64,..." width="1400">

# %% [markdown]
# ## Generate Source Position Lists
